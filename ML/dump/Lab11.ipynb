# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# - single linkage -- minimum distance between points in two clusters
# - complete linkage -- maximum distance between points in two clusters
# - average linkage -- average distance between all pairs of points in two clusters

# %%
X = pd.read_csv("data/data11.csv").to_numpy()
linked = linkage(X, 'single') # 'average', 'complete' also work
dendrogram(linked)

plt.xlabel('Point index')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %%
linked
# index of cluster 1, index of cluster 2, distance, size of final cluster
# Out:
# array([[ 3.        ,  6.        ,  1.41421356,  2.        ],
#        [ 4.        ,  7.        ,  1.41421356,  2.        ],
#        [ 0.        ,  1.        ,  2.23606798,  2.        ],
#        [ 2.        , 10.        ,  2.23606798,  3.        ],
#        [ 8.        , 11.        ,  2.82842712,  3.        ],
#        [ 9.        , 13.        ,  3.60555128,  5.        ],
#        [12.        , 14.        ,  4.        ,  8.        ],
#        [ 5.        , 15.        ,  4.12310563,  9.        ]])
