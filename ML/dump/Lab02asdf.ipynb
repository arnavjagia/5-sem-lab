# %% [markdown]
# [Creating multiple subplots](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html) -- Pandas docs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
X = [2, 4, 5, 7, 9]
Y = [5, 4, 10, 2, 8]

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Random charts')
fig.supxlabel("x label")
fig.supylabel("y label")

axes[0, 0].set_title('Line plot')
axes[0, 0].plot(X, Y)
# axes[0, 0].set_xlabel("axes[0, 0]'s own xlabel")

axes[0, 1].set_title('Bar chart')
axes[0, 1].bar(X, Y)

axes[1, 0].set_title('Scatter plot')
axes[1, 0].scatter(X, Y)

distribution = np.random.normal(170, 10, 250) 
axes[1, 1].set_title('Histogram')
axes[1, 1].hist(distribution)

plt.show()

# %%
df = pd.DataFrame({
    'fruit': ['apple', 'orange'],
    'quantity': [1, 2]
})
df.head()
# Out:
#     fruit  quantity
# 0   apple         1
# 1  orange         2

# %%
series = pd.Series([0, 1, 2])  # Series is essentially a column
print(series[0])  # 0 

series = pd.Series([0, 1, 2], index=['a', 'b', 'c'])  # custom indexing
print(series['a'])  # 0

series[series > 1]  # c 2 (only index c satisfies the constraint)
# Out:
# 0
# 0
# c    2
# dtype: int64
